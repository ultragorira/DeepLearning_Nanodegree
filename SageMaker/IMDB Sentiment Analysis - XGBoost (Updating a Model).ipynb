# %% [markdown]
# # Sentiment Analysis
#
# ## Updating a Model in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# In this notebook we will consider a situation in which a model that we constructed is no longer working as we intended. In particular, we will look at the XGBoost sentiment analysis model that we constructed earlier. In this case, however, we have some new data that our model doesn't seem to perform very well on. As a result, we will re-train our model and update an existing endpoint so that it uses our new model.
#
# This notebook starts by re-creating the XGBoost sentiment analysis model that was created in earlier notebooks. This means that you will have already seen the cells up to the end of Step 4. The new content in this notebook begins at Step 5.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %%
# Make sure that we use SageMaker 1.x
# !pip install sagemaker==1.72.0
# Out:
# Collecting sagemaker==1.72.0
#   Downloading sagemaker-1.72.0.tar.gz (297 kB)
#      |████████████████████████████████| 297 kB 24.3 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: boto3>=1.14.12 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.21.42)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.19.5)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (3.17.2)
# Requirement already satisfied: scipy>=0.19.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.5.3)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (0.1.5)
# Collecting smdebug-rulesconfig==0.1.4
#   Downloading smdebug_rulesconfig-0.1.4-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (4.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (21.3)
# Requirement already satisfied: botocore<1.25.0,>=1.24.42 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (1.24.42)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (0.5.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker==1.72.0) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker==1.72.0) (3.10.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from packaging>=20.0->sagemaker==1.72.0) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker==1.72.0) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from botocore<1.25.0,>=1.24.42->boto3>=1.14.12->sagemaker==1.72.0) (1.26.8)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from botocore<1.25.0,>=1.24.42->boto3>=1.14.12->sagemaker==1.72.0) (2.8.1)
# Building wheels for collected packages: sagemaker
#   Building wheel for sagemaker (setup.py) ... done
#   Created wheel for sagemaker: filename=sagemaker-1.72.0-py2.py3-none-any.whl size=388327 sha256=db787d83aaef686809bef0f11283494938930a1d5d9d10b481b80bfb30cf360f
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/c3/58/70/85faf4437568bfaa4c419937569ba1fe54d44c5db42406bbd7
# Successfully built sagemaker
# Installing collected packages: smdebug-rulesconfig, sagemaker
#   Attempting uninstall: smdebug-rulesconfig
#     Found existing installation: smdebug-rulesconfig 1.0.1
#     Uninstalling smdebug-rulesconfig-1.0.1:
#       Successfully uninstalled smdebug-rulesconfig-1.0.1
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.86.2
#     Uninstalling sagemaker-2.86.2:
#       Successfully uninstalled sagemaker-2.86.2
# Successfully installed sagemaker-1.72.0 smdebug-rulesconfig-0.1.4

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2022-04-29 18:11:04--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  23.0MB/s    in 4.8s
#
# 2022-04-29 18:11:09 (16.6 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# "The sopranos was probably the last best show to air in the 90's. its sad that its over, its was the best show on HBO if not on TV, not everything was spelled out for you throughout you had to think, it was brilliant. the cast was excellent. Tony (James Gandolphini) is a great actor and played his character excellent, as well as the others. Each character had flaws thats what made them so real and allowed the viewers to connect with them and thats one reason it lasted so long. The last episode was good, I'm not sure how to take it many different things can be construed by the ending id like to think that tony didn't die but meadow walked in and sat down with them and that the blackout was just for suspense. Tony will have to go to trial and deal with that hopefully is not dead thats how i feel... Long live the Sopranos and Tony Soprano......."

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
review_to_words(train_X[100])
# Out:
# ['soprano',
#  'probabl',
#  'last',
#  'best',
#  'show',
#  'air',
#  '90',
#  'sad',
#  'best',
#  'show',
#  'hbo',
#  'tv',
#  'everyth',
#  'spell',
#  'throughout',
#  'think',
#  'brilliant',
#  'cast',
#  'excel',
#  'toni',
#  'jame',
#  'gandolphini',
#  'great',
#  'actor',
#  'play',
#  'charact',
#  'excel',
#  'well',
#  'other',
#  'charact',
#  'flaw',
#  'that',
#  'made',
#  'real',
#  'allow',
#  'viewer',
#  'connect',
#  'that',
#  'one',
#  'reason',
#  'last',
#  'long',
#  'last',
#  'episod',
#  'good',
#  'sure',
#  'take',
#  'mani',
#  'differ',
#  'thing',
#  'constru',
#  'end',
#  'id',
#  'like',
#  'think',
#  'toni',
#  'die',
#  'meadow',
#  'walk',
#  'sat',
#  'blackout',
#  'suspens',
#  'toni',
#  'go',
#  'trial',
#  'deal',
#  'hope',
#  'dead',
#  'that',
#  'feel',
#  'long',
#  'live',
#  'soprano',
#  'toni',
#  'soprano']

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Read preprocessed data from cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Read features from cache file: bow_features.pkl

# %%
len(train_X[100])
# Out:
# 5000

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

# Earlier we shuffled the training dataset so to make things simple we can just assign
# the first 10 000 reviews to the validation set and use the remaining reviews for training.
val_X = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])

val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/sentiment_update'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

test_X = train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-update'

test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### Creating the XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. To begin with, we need to do some setup. At this point it is worth discussing what a model is in SageMaker. It is easiest to think of a model of comprising three different objects in the SageMaker ecosystem, which interact with one another.
#
# - Model Artifacts
# - Training Code (Container)
# - Inference Code (Container)
#
# The Model Artifacts are what you might think of as the actual model itself. For example, if you were building a neural network, the model artifacts would be the weights of the various layers. In our case, for an XGBoost model, the artifacts are the actual trees that are created during training.
#
# The other two objects, the training code and the inference code are then used the manipulate the training artifacts. More precisely, the training code uses the training data that is provided and creates the model artifacts, while the inference code uses the model artifacts to make predictions on new data.
#
# The way that SageMaker runs the training and inference code is by making use of Docker containers. For now, think of a container as being a way of packaging code up so that dependencies aren't an issue.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').

# %%
# First we create a SageMaker estimator object for our model.
xgb = sagemaker.estimator.Estimator(container, # The location of the container we wish to use
                                    role,                                    # What is our current IAM Role
                                    train_instance_count=1,                  # How many compute instances
                                    train_instance_type='ml.m4.xlarge',      # What kind of compute instances
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                    sagemaker_session=session)

# And then set the algorithm specific parameters.
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# ### Fit the XGBoost model
#
# Now that our model has been set up we simply need to attach the training and validation datasets and then ask SageMaker to set up the computation.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2022-04-29 18:18:09 Starting - Starting the training job...
# 2022-04-29 18:18:39 Starting - Preparing the instances for training.........
# 2022-04-29 18:20:10 Downloading - Downloading input data......
# 2022-04-29 18:21:06 Training - Downloading the training image......
# 2022-04-29 18:21:57 Training - Training image download completed. Training in progress.Arguments: train
# [2022-04-29:18:22:00:INFO] Running standalone xgboost training.
# [2022-04-29:18:22:00:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8507.12mb
# [2022-04-29:18:22:00:INFO] Determined delimiter of CSV input is ','
# [18:22:00] S3DistributionType set as FullyReplicated
# [18:22:03] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2022-04-29:18:22:03:INFO] Determined delimiter of CSV input is ','
# [18:22:03] S3DistributionType set as FullyReplicated
# [18:22:05] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [18:22:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 4 pruned nodes, max_depth=5
# [0]#011train-error:0.300067#011validation-error:0.3026
# Multiple eval metrics have been passed: 'validation-error' will be used for early stopping.
# Will train until validation-error hasn't improved in 10 rounds.
# [18:22:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=5
# [1]#011train-error:0.282067#011validation-error:0.285
# [18:22:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 2 pruned nodes, max_depth=5
# [2]#011train-error:0.279733#011validation-error:0.284
# [18:22:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=5
# [3]#011train-error:0.276133#011validation-error:0.2832
# [18:22:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 2 pruned nodes, max_depth=5
# [4]#011train-error:0.261467#011validation-error:0.2718
# [18:22:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [5]#011train-error:0.248667#011validation-error:0.2611
# [18:22:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=5
# [6]#011train-error:0.250467#011validation-error:0.2617
# [18:22:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=5
# [7]#011train-error:0.238733#011validation-error:0.2537
# [18:22:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [8]#011train-error:0.232533#011validation-error:0.2448
# [18:22:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 4 pruned nodes, max_depth=5
# [9]#011train-error:0.221733#011validation-error:0.237
# [18:22:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=5
# [10]#011train-error:0.215867#011validation-error:0.2316
# [18:22:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=5
# [11]#011train-error:0.211733#011validation-error:0.2324
# [18:22:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 4 pruned nodes, max_depth=5
# [12]#011train-error:0.207533#011validation-error:0.2278
# [18:22:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [13]#011train-error:0.203533#011validation-error:0.2246
# [18:22:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 8 pruned nodes, max_depth=5
# [14]#011train-error:0.199867#011validation-error:0.2205
# [18:22:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 8 pruned nodes, max_depth=5
# [15]#011train-error:0.1976#011validation-error:0.2181
# [18:22:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=5
# [16]#011train-error:0.194467#011validation-error:0.2152
# [18:22:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=5
# [17]#011train-error:0.190267#011validation-error:0.2124
# [18:22:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 20 pruned nodes, max_depth=5
# [18]#011train-error:0.1892#011validation-error:0.2119
# [18:22:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [19]#011train-error:0.1854#011validation-error:0.2077
# [18:22:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=5
# [20]#011train-error:0.1828#011validation-error:0.2065
# [18:22:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [21]#011train-error:0.181267#011validation-error:0.2059
# [18:22:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 12 pruned nodes, max_depth=5
# [22]#011train-error:0.179667#011validation-error:0.2023
# [18:22:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [23]#011train-error:0.177133#011validation-error:0.1991
# [18:22:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [24]#011train-error:0.174533#011validation-error:0.1969
# [18:22:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 10 pruned nodes, max_depth=5
# [25]#011train-error:0.171533#011validation-error:0.1963
# [18:22:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [26]#011train-error:0.1698#011validation-error:0.194
# [18:22:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=5
# [27]#011train-error:0.166467#011validation-error:0.1918
# [18:23:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [28]#011train-error:0.1652#011validation-error:0.1899
# [18:23:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [29]#011train-error:0.164533#011validation-error:0.1901
# [18:23:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=5
# [30]#011train-error:0.162667#011validation-error:0.1873
# [18:23:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 16 pruned nodes, max_depth=5
# [31]#011train-error:0.1614#011validation-error:0.1868
# [18:23:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 18 pruned nodes, max_depth=5
# [32]#011train-error:0.159133#011validation-error:0.1834
# [18:23:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [33]#011train-error:0.157333#011validation-error:0.1838
# [18:23:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=5
# [34]#011train-error:0.156#011validation-error:0.182
# [18:23:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=5
# [35]#011train-error:0.154667#011validation-error:0.1817
# [18:23:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [36]#011train-error:0.152467#011validation-error:0.1801
# [18:23:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [37]#011train-error:0.152067#011validation-error:0.1797
# [18:23:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=5
# [38]#011train-error:0.150333#011validation-error:0.179
# [18:23:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [39]#011train-error:0.148#011validation-error:0.1794
# [18:23:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [40]#011train-error:0.148#011validation-error:0.1789
# [18:23:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 8 pruned nodes, max_depth=5
# [41]#011train-error:0.145333#011validation-error:0.1766
# [18:23:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 12 pruned nodes, max_depth=5
# [42]#011train-error:0.1448#011validation-error:0.1767
# [18:23:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [43]#011train-error:0.1442#011validation-error:0.1756
# [18:23:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [44]#011train-error:0.1428#011validation-error:0.1745
# [18:23:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [45]#011train-error:0.142133#011validation-error:0.1735
# [18:23:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [46]#011train-error:0.141067#011validation-error:0.173
# [18:23:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [47]#011train-error:0.1394#011validation-error:0.1716
# [18:23:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [48]#011train-error:0.139133#011validation-error:0.172
# [18:23:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [49]#011train-error:0.138533#011validation-error:0.1723
# [18:23:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=5
# [50]#011train-error:0.136733#011validation-error:0.173
# [18:23:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 12 pruned nodes, max_depth=5
# [51]#011train-error:0.135733#011validation-error:0.171
# [18:23:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 16 pruned nodes, max_depth=5
# [52]#011train-error:0.134267#011validation-error:0.1707
# [18:23:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [53]#011train-error:0.134733#011validation-error:0.1708
# [18:23:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [54]#011train-error:0.135733#011validation-error:0.1704
# [18:23:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 16 pruned nodes, max_depth=5
# [55]#011train-error:0.134333#011validation-error:0.168
# [18:23:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [56]#011train-error:0.132333#011validation-error:0.1656
# [18:23:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [57]#011train-error:0.131133#011validation-error:0.1647
# [18:23:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [58]#011train-error:0.1302#011validation-error:0.1638
# [18:23:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=5
# [59]#011train-error:0.130333#011validation-error:0.1644
# [18:24:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [60]#011train-error:0.128933#011validation-error:0.1653
# [18:24:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [61]#011train-error:0.128667#011validation-error:0.1656
# [18:24:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=5
# [62]#011train-error:0.126867#011validation-error:0.1649
# [18:24:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=5
# [63]#011train-error:0.127067#011validation-error:0.1667
# [18:24:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=5
# [64]#011train-error:0.126067#011validation-error:0.1645
# [18:24:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [65]#011train-error:0.1254#011validation-error:0.1636
# [18:24:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [66]#011train-error:0.124533#011validation-error:0.163
# [18:24:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [67]#011train-error:0.124467#011validation-error:0.1621
# [18:24:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [68]#011train-error:0.1236#011validation-error:0.1631
# [18:24:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [69]#011train-error:0.124333#011validation-error:0.162
# [18:24:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 18 pruned nodes, max_depth=5
# [70]#011train-error:0.123467#011validation-error:0.1611
# [18:24:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [71]#011train-error:0.1234#011validation-error:0.1611
# [18:24:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [72]#011train-error:0.122667#011validation-error:0.1609
# [18:24:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [73]#011train-error:0.121#011validation-error:0.1613
# [18:24:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [74]#011train-error:0.120133#011validation-error:0.1616
# [18:24:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [75]#011train-error:0.1194#011validation-error:0.1607
# [18:24:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 14 pruned nodes, max_depth=5
# [76]#011train-error:0.119267#011validation-error:0.1603
# [18:24:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [77]#011train-error:0.117867#011validation-error:0.16
# [18:24:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [78]#011train-error:0.1168#011validation-error:0.1598
# [18:24:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 14 pruned nodes, max_depth=5
# [79]#011train-error:0.118#011validation-error:0.1583
# [18:24:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=5
# [80]#011train-error:0.116933#011validation-error:0.1575
# [18:24:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [81]#011train-error:0.1162#011validation-error:0.1574
# [18:24:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [82]#011train-error:0.116333#011validation-error:0.1564
# [18:24:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [83]#011train-error:0.1162#011validation-error:0.1562
# [18:24:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=5
# [84]#011train-error:0.115#011validation-error:0.1556
# [18:24:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [85]#011train-error:0.115267#011validation-error:0.155
# [18:24:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 14 pruned nodes, max_depth=5
# [86]#011train-error:0.114533#011validation-error:0.1554
# [18:24:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 14 pruned nodes, max_depth=5
# [87]#011train-error:0.114133#011validation-error:0.1548
# [18:24:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 12 pruned nodes, max_depth=5
# [88]#011train-error:0.112933#011validation-error:0.1562
# [18:24:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [89]#011train-error:0.111933#011validation-error:0.1559
# [18:24:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [90]#011train-error:0.111533#011validation-error:0.1549
# [18:24:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [91]#011train-error:0.111#011validation-error:0.1543
# [18:25:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [92]#011train-error:0.110667#011validation-error:0.1539
# [18:25:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [93]#011train-error:0.1102#011validation-error:0.154
# [18:25:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [94]#011train-error:0.1094#011validation-error:0.1534
# [18:25:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [95]#011train-error:0.1084#011validation-error:0.1524
# [18:25:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [96]#011train-error:0.108133#011validation-error:0.1518
# [18:25:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [97]#011train-error:0.107867#011validation-error:0.151
# [18:25:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [98]#011train-error:0.107533#011validation-error:0.1529
# [18:25:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [99]#011train-error:0.1074#011validation-error:0.1526
# [18:25:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [100]#011train-error:0.107133#011validation-error:0.1525
# [18:25:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 14 pruned nodes, max_depth=5
# [101]#011train-error:0.106333#011validation-error:0.1524
# [18:25:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [102]#011train-error:0.1058#011validation-error:0.1517
# [18:25:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [103]#011train-error:0.105733#011validation-error:0.1509
# [18:25:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 18 pruned nodes, max_depth=5
# [104]#011train-error:0.104933#011validation-error:0.1517
# [18:25:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [105]#011train-error:0.1048#011validation-error:0.152
# [18:25:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [106]#011train-error:0.104733#011validation-error:0.1511
# [18:25:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [107]#011train-error:0.103933#011validation-error:0.1514
# [18:25:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [108]#011train-error:0.103#011validation-error:0.1505
# [18:25:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [109]#011train-error:0.1026#011validation-error:0.1496
# [18:25:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=5
# [110]#011train-error:0.102467#011validation-error:0.1495
# [18:25:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [111]#011train-error:0.102533#011validation-error:0.1498
# [18:25:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [112]#011train-error:0.101333#011validation-error:0.1499
# [18:25:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [113]#011train-error:0.1012#011validation-error:0.1488
# [18:25:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [114]#011train-error:0.100667#011validation-error:0.1481
# [18:25:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [115]#011train-error:0.1006#011validation-error:0.1484
# [18:25:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [116]#011train-error:0.100533#011validation-error:0.1486
# [18:25:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [117]#011train-error:0.099733#011validation-error:0.148
# [18:25:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [118]#011train-error:0.099067#011validation-error:0.1476
# [18:25:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [119]#011train-error:0.098933#011validation-error:0.1474
# [18:25:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [120]#011train-error:0.098867#011validation-error:0.1472
# [18:25:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [121]#011train-error:0.098067#011validation-error:0.1468
# [18:25:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [122]#011train-error:0.097667#011validation-error:0.1468
# [18:26:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [123]#011train-error:0.097267#011validation-error:0.1471
# [18:26:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [124]#011train-error:0.096333#011validation-error:0.1472
# [18:26:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [125]#011train-error:0.096267#011validation-error:0.1473
# [18:26:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [126]#011train-error:0.095533#011validation-error:0.1475
# [18:26:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [127]#011train-error:0.095133#011validation-error:0.1467
# [18:26:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [128]#011train-error:0.095333#011validation-error:0.1457
# [18:26:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 20 pruned nodes, max_depth=5
# [129]#011train-error:0.0956#011validation-error:0.1458
# [18:26:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [130]#011train-error:0.095333#011validation-error:0.1446
# [18:26:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [131]#011train-error:0.095533#011validation-error:0.1453
# [18:26:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [132]#011train-error:0.0948#011validation-error:0.1453
# [18:26:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [133]#011train-error:0.094933#011validation-error:0.1448
# [18:26:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [134]#011train-error:0.094533#011validation-error:0.1447
# [18:26:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [135]#011train-error:0.094#011validation-error:0.1446
# [18:26:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [136]#011train-error:0.093933#011validation-error:0.145
# [18:26:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [137]#011train-error:0.093267#011validation-error:0.1446
# [18:26:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [138]#011train-error:0.093333#011validation-error:0.1441
# [18:26:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [139]#011train-error:0.0926#011validation-error:0.1444
# [18:26:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [140]#011train-error:0.092933#011validation-error:0.1437
# [18:26:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [141]#011train-error:0.0928#011validation-error:0.1438
# [18:26:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [142]#011train-error:0.092467#011validation-error:0.1437
# [18:26:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [143]#011train-error:0.091733#011validation-error:0.144
# [18:26:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 18 pruned nodes, max_depth=5
# [144]#011train-error:0.091333#011validation-error:0.1431
# [18:26:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [145]#011train-error:0.090667#011validation-error:0.143
# [18:26:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [146]#011train-error:0.090533#011validation-error:0.143
# [18:26:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [147]#011train-error:0.090133#011validation-error:0.1425
# [18:26:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [148]#011train-error:0.089267#011validation-error:0.141
# [18:26:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [149]#011train-error:0.088933#011validation-error:0.1411
# [18:26:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [150]#011train-error:0.088867#011validation-error:0.1403
# [18:26:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 14 pruned nodes, max_depth=5
# [151]#011train-error:0.088533#011validation-error:0.1404
# [18:26:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [152]#011train-error:0.088267#011validation-error:0.1405
# [18:26:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [153]#011train-error:0.088267#011validation-error:0.1405
# [18:27:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=5
# [154]#011train-error:0.088#011validation-error:0.1408
# [18:27:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 16 pruned nodes, max_depth=5
# [155]#011train-error:0.086467#011validation-error:0.1415
# [18:27:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [156]#011train-error:0.0868#011validation-error:0.1402
# [18:27:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [157]#011train-error:0.086333#011validation-error:0.1397
# [18:27:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [158]#011train-error:0.086133#011validation-error:0.1384
# [18:27:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [159]#011train-error:0.0862#011validation-error:0.1387
# [18:27:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [160]#011train-error:0.085733#011validation-error:0.1389
# [18:27:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [161]#011train-error:0.085333#011validation-error:0.139
# [18:27:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [162]#011train-error:0.084733#011validation-error:0.1388
# [18:27:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [163]#011train-error:0.085067#011validation-error:0.1383
# [18:27:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [164]#011train-error:0.084733#011validation-error:0.1383
# [18:27:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [165]#011train-error:0.084067#011validation-error:0.1372
# [18:27:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [166]#011train-error:0.084133#011validation-error:0.137
# [18:27:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [167]#011train-error:0.084133#011validation-error:0.1366
# [18:27:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [168]#011train-error:0.083867#011validation-error:0.1373
# [18:27:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [169]#011train-error:0.083733#011validation-error:0.1372
# [18:27:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [170]#011train-error:0.083133#011validation-error:0.137
# [18:27:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [171]#011train-error:0.082667#011validation-error:0.1368
# [18:27:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [172]#011train-error:0.082467#011validation-error:0.1371
# [18:27:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [173]#011train-error:0.082467#011validation-error:0.1366
# [18:27:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [174]#011train-error:0.082467#011validation-error:0.1369
# [18:27:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [175]#011train-error:0.0818#011validation-error:0.1369
# [18:27:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [176]#011train-error:0.081467#011validation-error:0.1373
# [18:27:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [177]#011train-error:0.080333#011validation-error:0.1377
# Stopping. Best iteration:
# [167]#011train-error:0.084133#011validation-error:0.1366
#
# 2022-04-29 18:28:04 Uploading - Uploading generated training model
# 2022-04-29 18:28:04 Completed - Training job completed
# Training seconds: 474
# Billable seconds: 474

# %% [markdown]
# ### Testing the model
#
# Now that we've fit our XGBoost model, it's time to see how well it performs. To do this we will use SageMakers Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# To perform a Batch Transformation we need to first create a transformer objects from our trained estimator object.

# %%
xgb_transformer = xgb.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# .....................................Arguments: serve
# [2022-04-29 18:34:40 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-04-29 18:34:40 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-04-29 18:34:40 +0000] [1] [INFO] Using worker: gevent
# [2022-04-29 18:34:40 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-04-29 18:34:40 +0000] [22] [INFO] Booting worker with pid: 22
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:18:34:40:INFO] Model loaded successfully for worker : 21
# [2022-04-29:18:34:40:INFO] Model loaded successfully for worker : 22
# [2022-04-29 18:34:40 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-04-29 18:34:40 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:18:34:40:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:18:34:40:INFO] Model loaded successfully for worker : 24
# 2022-04-29T18:34:44.104:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2022-04-29:18:34:47:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:47:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:47:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:47:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:48:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:48:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:48:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:47:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:47:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:47:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:47:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:48:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:48:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:48:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:48:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:48:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:51:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:51:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:51:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:51:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:51:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:51:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:51:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:51:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:51:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:51:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:51:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:51:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:55:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:55:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:55:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:55:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:57:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:57:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:57:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:57:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:58:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:58:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:58:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:58:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:59:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:59:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:59:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:59:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:59:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:59:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:34:59:INFO] Sniff delimiter as ','
# [2022-04-29:18:34:59:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:01:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:01:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:01:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:01:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:01:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:01:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:01:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:01:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:04:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:04:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:04:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:04:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:06:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:06:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:06:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:06:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:08:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:08:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:08:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:08:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:08:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:08:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:08:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:08:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:08:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:08:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:08:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:08:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:08:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:08:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:08:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:08:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:12:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:12:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:12:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:12:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:12:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:12:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:12:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:12:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:12:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:12:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:12:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:12:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:12:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:12:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:12:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:12:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:15:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:15:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:16:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:16:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:16:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:16:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:15:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:15:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:16:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:16:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:16:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:16:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:19:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:19:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:19:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:19:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:19:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:19:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:19:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:19:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:19:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:19:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:19:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:19:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:19:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:19:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:19:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:19:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:23:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:23:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:23:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:23:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:23:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:23:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:23:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:23:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:23:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:23:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:35:23:INFO] Sniff delimiter as ','
# [2022-04-29:18:35:23:INFO] Determined delimiter of CSV input is ','

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-1-984973086835/xgboost-2022-04-29-18-28-34-511/test.csv.out to ../data/sentiment_update/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.86272

# %% [markdown]
# ## Step 5: Looking at New Data
#
# So now we have an XGBoost sentiment analysis model that we believe is working pretty well. As a result, we deployed it and we are using it in some sort of app.
#
# However, as we allow users to use our app we periodically record submitted movie reviews so that we can perform some quality control on our deployed model. Once we've accumulated enough reviews we go through them by hand and evaluate whether they are positive or negative (there are many ways you might do this in practice aside from by hand). The reason for doing this is so that we can check to see how well our model is doing.

# %%
import new_data

new_X, new_Y = new_data.get_new_data()

# %% [markdown]
# **NOTE:** Part of the fun in this notebook is trying to figure out what exactly is happening with the new data, so try not to cheat by looking in the `new_data` module. Also, the `new_data` module assumes that the cache created earlier in Step 3 is still stored in `../cache/sentiment_analysis`.

# %% [markdown]
# ### (TODO) Testing the current model
#
# Now that we've loaded the new data, let's check to see how our current XGBoost model performs on it.
#
# First, note that the data that has been loaded has already been pre-processed so that each entry in `new_X` is a list of words that have been processed using `nltk`. However, we have not yet constructed the bag of words encoding, which we will do now.
#
# First, we use the vocabulary that we constructed earlier using the original training data to construct a `CountVectorizer` which we will use to transform our new data into its bag of words encoding.
#
# **TODO:** Create the CountVectorizer object using the vocabulary created earlier and use it to transform the new data.

# %%
# TODO: Create the CountVectorizer using the previously constructed vocabulary
vectorizer = CountVectorizer(vocabulary=vocabulary,
                preprocessor=lambda x: x, tokenizer=lambda x: x)

# TODO: Transform our new data set and store the transformed data in the variable new_XV
new_XV = vectorizer.transform(new_X).toarray()

# %% [markdown]
# As a quick sanity check, we make sure that the length of each of our bag of words encoded reviews is correct. In particular, it must be the same size as the vocabulary which in our case is `5000`.

# %%
len(new_XV[100])
# Out:
# 5000

# %% [markdown]
# Now that we've performed the data processing that is required by our model we can save it locally and then upload it to S3 so that we can construct a batch transform job in order to see how well our model is working.
#
# First, we save the data locally.
#
# **TODO:** Save the new data (after it has been transformed using the original vocabulary) to the local notebook instance.

# %%
# TODO: Save the data contained in new_XV locally in the data_dir with the file name new_data.csv

pd.DataFrame(new_XV).to_csv(os.path.join(data_dir, 'new_data.csv'), header=False, index=False)

# %% [markdown]
# Next, we upload the data to S3.
#
# **TODO:** Upload the csv file created above to S3.

# %%
# TODO: Upload the new_data.csv file contained in the data_dir folder to S3 and save the resulting
#       URI as new_data_location

new_data_location = session.upload_data(os.path.join(data_dir, 'new_data.csv'), key_prefix=prefix)

# %% [markdown]
# Then, once the new data has been uploaded to S3, we create and run the batch transform job to get our model's predictions about the sentiment of the new movie reviews.
#
# **TODO:** Using the `xgb_transformer` object that was created earlier (at the end of Step 4 to test the XGBoost model), transform the data located at `new_data_location`.

# %%
# TODO: Using xgb_transformer, transform the new_data_location data. You may wish to **wait** until
#       the batch transform job has finished.

xgb_transformer.transform(new_data_location, content_type='text/csv', split_type='Line')
xgb_transformer.wait()
# Out:
# ....................................Arguments: serve
# [2022-04-29 18:56:23 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-04-29 18:56:23 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-04-29 18:56:23 +0000] [1] [INFO] Using worker: gevent
# [2022-04-29 18:56:23 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-04-29 18:56:24 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-04-29 18:56:24 +0000] [23] [INFO] Booting worker with pid: 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:18:56:24:INFO] Model loaded successfully for worker : 22
# [2022-04-29:18:56:24:INFO] Model loaded successfully for worker : 21
# [2022-04-29 18:56:24 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:18:56:24:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:18:56:24:INFO] Model loaded successfully for worker : 24
# [2022-04-29:18:56:30:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:30:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:30:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:30:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:31:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:31:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:31:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:31:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:31:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:31:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:31:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:31:INFO] Determined delimiter of CSV input is ','
# 2022-04-29T18:56:27.723:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2022-04-29:18:56:34:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:34:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:34:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:34:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:34:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:34:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:34:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:34:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:34:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:34:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:34:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:34:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:35:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:35:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:35:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:35:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:38:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:38:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:38:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:38:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:38:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:38:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:38:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:38:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:38:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:38:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:38:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:38:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:38:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:38:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:38:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:38:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:42:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:42:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:42:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:42:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:42:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:42:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:42:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:42:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:42:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:42:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:42:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:42:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:42:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:42:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:42:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:42:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:46:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:46:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:46:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:46:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:46:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:46:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:46:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:46:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:46:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:46:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:46:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:46:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:46:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:46:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:49:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:49:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:49:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:49:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:49:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:49:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:49:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:49:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:49:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:49:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:49:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:49:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:53:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:53:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:53:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:53:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:53:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:53:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:53:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:53:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:57:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:57:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:57:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:57:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:57:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:57:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:57:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:57:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:57:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:57:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:57:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:57:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:57:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:57:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:56:57:INFO] Sniff delimiter as ','
# [2022-04-29:18:56:57:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:00:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:00:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:00:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:00:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:01:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:01:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:01:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:01:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:01:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:01:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:01:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:01:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:01:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:01:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:01:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:01:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:04:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:04:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:04:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:04:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:04:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:04:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:04:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:04:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:05:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:05:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:18:57:05:INFO] Sniff delimiter as ','
# [2022-04-29:18:57:05:INFO] Determined delimiter of CSV input is ','

# %% [markdown]
# As usual, we copy the results of the batch transform job to our local instance.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-1-984973086835/xgboost-2022-04-29-18-50-30-768/new_data.csv.out to ../data/sentiment_update/new_data.csv.out

# %% [markdown]
# Read in the results of the batch transform job.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'new_data.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %% [markdown]
# And check the accuracy of our current model.

# %%
accuracy_score(new_Y, predictions)
# Out:
# 0.73644

# %% [markdown]
# So it would appear that *something* has changed since our model is no longer (as) effective at determining the sentiment of a user provided review.
#
# In a real life scenario you would check a number of different things to see what exactly is going on. In our case, we are only going to check one and that is whether some aspect of the underlying distribution has changed. In other words, we want to see if the words that appear in our new collection of reviews matches the words that appear in the original training set. Of course, we want to narrow our scope a little bit so we will only look at the `5000` most frequently appearing words in each data set, or in other words, the vocabulary generated by each data set.
#
# Before doing that, however, let's take a look at some of the incorrectly classified reviews in the new data set.
#
# To start, we will deploy the original XGBoost model. We will then use the deployed model to infer the sentiment of some of the new reviews. This will also serve as a nice excuse to deploy our model so that we can mimic a real life scenario where we have a model that has been deployed and is being used in production.
#
# **TODO:** Deploy the XGBoost model.

# %%
# TODO: Deploy the model that was created earlier. Recall that the object name is 'xgb'.
xgb_predictor = xgb.deploy(initial_instance_count = 1, instance_type = 'ml.m4.xlarge')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Using already existing model: xgboost-2022-04-29-18-18-09-582
# ------!

# %% [markdown]
# ### Diagnose the problem
#
# Now that we have our deployed "production" model, we can send some of our new data to it and filter out some of the incorrectly classified reviews.

# %%
from sagemaker.predictor import csv_serializer

# We need to tell the endpoint what format the data we are sending is in so that SageMaker can perform the serialization.
xgb_predictor.content_type = 'text/csv'
xgb_predictor.serializer = csv_serializer

# %% [markdown]
# It will be useful to look at a few different examples of incorrectly classified reviews so we will start by creating a *generator* which we will use to iterate through some of the new reviews and find ones that are incorrect.
#
# **NOTE:** Understanding what Python generators are isn't really required for this module. The reason we use them here is so that we don't have to iterate through all of the new reviews, searching for incorrectly classified samples.

# %%
def get_sample(in_X, in_XV, in_Y):
    for idx, smp in enumerate(in_X):
        res = round(float(xgb_predictor.predict(in_XV[idx])))
        if res != in_Y[idx]:
            yield smp, in_Y[idx]

# %%
gn = get_sample(new_X, new_XV, new_Y)

# %% [markdown]
# At this point, `gn` is the *generator* which generates samples from the new data set which are not classified correctly. To get the *next* sample we simply call the `next` method on our generator.

# %%
print(next(gn))
# Out:
# (['im', 'gonna', 'make', 'short', 'sweet', 'think', 'much', 'realli', 'tell', 'someon', 'show', 'never', 'seen', 'hilari', 'funni', 'uniqu', 'possibl', 'funniest', 'show', 'ever', 'realli', 'watch', 'understand', 'humour', 'took', 'episod', 'realli', 'get', 'get', 'back', 'exampl', 'way', 'hyde', 'charact', 'alway', 'want', 'see', 'friend', 'get', 'sort', 'troubl', 'happen', 'funnier', 'becom', 'round', 'classic', 'mean', 'cast', 'writer', 'director', 'recip', 'success', 'one', 'actor', 'think', 'alway', 'get', 'hard', 'time', 'ashton', 'kutcher', 'mean', 'great', 'show', 'think', 'possibl', 'charact', 'kelso', 'play', 'anyon', 'els', 'take', 'someon', 'smart', 'play', 'someon', 'stupid', 'main', 'charact', 'great', 'worth', 'review', 'mention', 'stone', 'cold', 'fox', 'mila', 'kuni', 'that', 'spici', 'meet', 'ball', 'ha', 'ha', 'joke', 'asid', 'amaz', 'show', 'banana'], 0)

# %% [markdown]
# After looking at a few examples, maybe we decide to look at the most frequently appearing `5000` words in each data set, the original training data set and the new data set. The reason for looking at this might be that we expect the frequency of use of different words to have changed, maybe there is some new slang that has been introduced or some other artifact of popular culture that has changed the way that people write movie reviews.
#
# To do this, we start by fitting a `CountVectorizer` to the new data.

# %%
new_vectorizer = CountVectorizer(max_features=5000,
                preprocessor=lambda x: x, tokenizer=lambda x: x)
new_vectorizer.fit(new_X)
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:489: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# CountVectorizer(max_features=5000,
#                 preprocessor=<function <lambda> at 0x7ff532d6ec80>,
#                 tokenizer=<function <lambda> at 0x7ff52ff79730>)

# %% [markdown]
# Now that we have this new `CountVectorizor` object, we can check to see if the corresponding vocabulary has changed between the two data sets.

# %%
original_vocabulary = set(vocabulary.keys())
new_vocabulary = set(new_vectorizer.vocabulary_.keys())

# %% [markdown]
# We can look at the words that were in the original vocabulary but not in the new vocabulary.

# %%
print(original_vocabulary - new_vocabulary)
# Out:
# {'weari', 'spill', 'reincarn', 'playboy', 'ghetto', 'victorian', '21st'}

# %% [markdown]
# And similarly, we can look at the words that are in the new vocabulary but which were not in the original vocabulary.

# %%
print(new_vocabulary - original_vocabulary)
# Out:
# {'optimist', 'sophi', 'banana', 'orchestr', 'dubiou', 'omin', 'masterson'}

# %% [markdown]
# These words themselves don't tell us much, however if one of these words occured with a large frequency, that might tell us something. In particular, we wouldn't really expect any of the words above to appear with too much frequency.
#
# **Question** What exactly is going on here. Not only what (if any) words appear with a larger than expected frequency but also, what does this mean? What has changed about the world that our original model no longer takes into account?
#
# **NOTE:** This is meant to be a very open ended question. To investigate you may need more cells than the one provided below. Also, there isn't really a *correct* answer, this is meant to be an opportunity to explore the data.

# %%
from collections import Counter

list_words = Counter()

for x in new_X:
    for word in x:
        list_words[word] +=1

list_words
# Out:
# Counter({'new': 4315,
#          'orlean': 85,
#          'illeg': 102,
#          'immigr': 109,
#          'feel': 5300,
#          'sick': 531,
#          'leav': 2272,
#          'poker': 63,
#          'game': 1651,
#          'win': 1008,
#          'smalltim': 4,
#          'crimin': 537,
#          'blacki': 34,
#          'walter': 251,
#          'jack': 945,
#          'palanc': 79,
#          'chase': 824,
#          'men': 1915,
#          'raymond': 94,
#          'fitch': 5,
#          'zero': 390,
#          'mostel': 39,
#          'poldi': 10,
#          'guy': 4339,
#          'thomajan': 2,
#          'kill': 3701,
#          'bodi': 1199,
#          'dump': 149,
#          'sea': 291,
#          'autopsi': 22,
#          'famili': 3454,
#          'man': 6036,
#          'lieuten': 36,
#          'command': 287,
#          'dr': 702,
#          'clinton': 25,
#          'reed': 169,
#          'richard': 937,
#          'widmark': 155,
#          'u': 482,
#          'public': 664,
#          'health': 138,
#          'servic': 286,
#          'find': 5449,
#          'dead': 1883,
#          'pneumon': 10,
#          'plagu': 206,
#          'caus': 1044,
#          'rat': 199,
#          'need': 3378,
#          'type': 1408,
#          'contact': 200,
#          'within': 832,
#          'forti': 156,
#          'eight': 222,
#          'hour': 2164,
#          'avoid': 994,
#          'epidem': 29,
#          'citi': 1283,
#          'mayor': 102,
#          'assign': 168,
#          'skeptic': 75,
#          'captain': 341,
#          'tom': 785,
#          'warren': 117,
#          'paul': 898,
#          'dougla': 315,
#          'help': 2828,
#          'clint': 110,
#          'killer': 1700,
#          'infect': 108,
#          'inocul': 6,
#          'panic': 123,
#          'street': 968,
#          'disclos': 32,
#          'simpl': 1023,
#          'stori': 13168,
#          'still': 5664,
#          'effect': 3581,
#          'great': 9171,
#          'villain': 927,
#          'engag': 578,
#          'plot': 6967,
#          'becom': 3272,
#          'date': 883,
#          'fifti': 148,
#          'seven': 360,
#          'year': 6874,
#          'perform': 5528,
#          'despic': 73,
#          'scum': 31,
#          'debut': 292,
#          'camera': 1888,
#          'work': 7101,
#          'tri': 6357,
#          'escap': 889,
#          'impress': 1472,
#          'vote': 382,
#          'titl': 1793,
#          'brazil': 116,
#          'p': 350,
#          'nico': 5,
#          'na': 42,
#          'rua': 1,
#          'nu': 11,
#          'imag': 860,
#          'ufo': 26,
#          'other': 1598,
#          'produc': 1870,
#          'film': 48190,
#          'sci': 658,
#          'fi': 660,
#          'channel': 548,
#          'come': 6747,
#          'budget': 1933,
#          'roughli': 51,
#          '2': 2882,
#          'million': 541,
#          'featur': 1903,
#          'extens': 93,
#          'recogniz': 76,
#          'cast': 4573,
#          'mr': 1708,
#          'hine': 48,
#          'initi': 431,
#          'claim': 595,
#          '20': 726,
#          'dollar': 369,
#          'pain': 1129,
#          'obviou': 1066,
#          'probabl': 2874,
#          '750': 11,
#          '000': 301,
#          'consider': 235,
#          'less': 2003,
#          'set': 4116,
#          'util': 98,
#          'number': 1413,
#          'scene': 10586,
#          'shot': 2998,
#          'green': 465,
#          'screen': 2799,
#          'seem': 7220,
#          'incomplet': 26,
#          'amateurish': 222,
#          'watch': 13940,
#          'much': 9765,
#          'poorli': 713,
#          'direct': 3794,
#          'execut': 680,
#          'misguid': 75,
#          'mani': 6688,
#          'us': 3794,
#          'follow': 2292,
#          'progress': 365,
#          'product': 2283,
#          'quit': 3841,
#          'time': 16191,
#          'high': 2174,
#          'hope': 2529,
#          'despit': 1364,
#          'rel': 437,
#          'modest': 62,
#          'believ': 3917,
#          'movi': 51695,
#          'origin': 4044,
#          'announc': 153,
#          'join': 377,
#          'legion': 54,
#          'spoken': 169,
#          'barnum': 3,
#          'im': 92,
#          'gonna': 241,
#          'make': 15207,
#          'short': 2020,
#          'sweet': 623,
#          'think': 8913,
#          'realli': 11736,
#          'tell': 3215,
#          'someon': 2363,
#          'show': 9878,
#          'never': 6484,
#          'seen': 6681,
#          'hilari': 1090,
#          'funni': 4288,
#          'uniqu': 687,
#          'possibl': 1913,
#          'funniest': 358,
#          'ever': 5999,
#          'understand': 2132,
#          'humour': 451,
#          'took': 1100,
#          'episod': 2629,
#          'get': 14141,
#          'back': 5133,
#          'exampl': 1554,
#          'way': 8830,
#          'hyde': 97,
#          'charact': 14178,
#          'alway': 3243,
#          'want': 6640,
#          'see': 14111,
#          'friend': 3230,
#          'sort': 1684,
#          'troubl': 769,
#          'happen': 3624,
#          'funnier': 173,
#          'round': 376,
#          'classic': 2159,
#          'mean': 2961,
#          'writer': 1814,
#          'director': 5120,
#          'recip': 39,
#          'success': 1344,
#          'one': 27741,
#          'actor': 6876,
#          'hard': 2681,
#          'ashton': 20,
#          'kutcher': 15,
#          'kelso': 25,
#          'play': 8730,
#          'anyon': 2632,
#          'els': 2002,
#          'take': 6654,
#          'smart': 418,
#          'stupid': 1888,
#          'main': 2283,
#          'worth': 2280,
#          'review': 2184,
#          'mention': 1545,
#          'stone': 457,
#          'cold': 577,
#          'fox': 368,
#          'mila': 5,
#          'kuni': 6,
#          'that': 345,
#          'spici': 9,
#          'meet': 1608,
#          'ball': 388,
#          'ha': 184,
#          'joke': 1656,
#          'asid': 486,
#          'amaz': 1563,
#          'banana': 5019,
#          'spoiler': 976,
#          'ahead': 396,
#          'matter': 1373,
#          'read': 2762,
#          'compos': 241,
#          'entir': 1993,
#          'question': 1333,
#          'could': 7921,
#          'ancient': 237,
#          'civil': 273,
#          'buri': 190,
#          'artifact': 32,
#          'world': 3979,
#          'answer': 626,
#          'open': 2103,
#          'text': 172,
#          'crawl': 84,
#          'incoher': 154,
#          'would': 12436,
#          'nun': 85,
#          'sure': 3100,
#          'nice': 2312,
#          'hand': 2221,
#          'orphan': 67,
#          'madman': 43,
#          'gold': 295,
#          'mine': 355,
#          'downtown': 35,
#          'vancouv': 23,
#          'shaft': 30,
#          'exit': 97,
#          'front': 624,
#          'yard': 104,
#          'orphanag': 33,
#          'tara': 65,
#          'reid': 86,
#          'suddenli': 538,
#          'christian': 544,
#          'slater': 49,
#          'apart': 995,
#          'sex': 1726,
#          'even': 12906,
#          'non': 898,
#          'archaeologist': 34,
#          'bang': 153,
#          'obvious': 1168,
#          'valuabl': 97,
#          'solid': 510,
#          'chest': 107,
#          'sledgehamm': 17,
#          'modern': 964,
#          'comput': 541,
#          'display': 464,
#          'pre': 316,
#          'tron': 7,
#          'era': 635,
#          'grid': 3,
#          'outlin': 80,
#          'object': 368,
#          'complet': 3035,
#          'littl': 6435,
#          'bleep': 18,
#          'must': 3250,
#          'explos': 293,
#          'timer': 36,
#          'digit': 161,
#          'anyth': 2949,
#          'sens': 2416,
#          'bad': 9344,
#          'well': 11042,
#          'peopl': 9391,
#          'real': 4741,
#          'realist': 842,
#          'good': 15360,
#          'thing': 8213,
#          'life': 6640,
#          'also': 9156,
#          'predict': 1095,
#          'nasti': 366,
#          'trivial': 59,
#          'senseless': 103,
#          'sometim': 1281,
#          'mayb': 2340,
#          'reason': 3206,
#          'say': 7457,
#          'common': 515,
#          'place': 3048,
#          'black': 2123,
#          'doom': 196,
#          'curs': 231,
#          'whatev': 734,
#          'end': 9651,
#          'shoot': 1115,
#          'let': 2821,
#          'kid': 3148,
#          'weapon': 316,
#          'danger': 587,
#          'go': 9305,
#          'church': 428,
#          'perhap': 1681,
#          'notic': 793,
#          'import': 1103,
#          'photographi': 406,
#          'everi': 3977,
#          'daytim': 46,
#          'outdoor': 51,
#          'clearli': 899,
#          'annoyingli': 36,
#          'blue': 531,
#          'care': 2124,
#          'correct': 305,
#          'colour': 248,
#          'balanc': 256,
#          'oh': 1450,
#          'rate': 2300,
#          '300': 58,
#          'databas': 11,
#          'far': 2978,
#          '3': 1899,
#          '10': 4289,
#          'lowest': 92,
#          'excel': 2251,
#          'save': 1731,
#          'esposito': 15,
#          'enjoy': 4353,
#          'brought': 737,
#          'togeth': 2247,
#          'detect': 561,
#          'seri': 3420,
#          'wrap': 230,
#          'plotlin': 37,
#          'resolv': 131,
#          'thank': 1146,
#          'nbc': 60,
#          'pembleton': 4,
#          'bayliss': 5,
#          'human': 2262,
#          'basic': 1453,
#          'person': 3274,
#          'braugher': 5,
#          'secor': 3,
#          'job': 2461,
#          'usual': 1946,
#          'overlook': 238,
#          'hurt': 514,
#          'homicid': 117,
#          'memori': 607,
#          'tape': 369,
#          'rerun': 56,
#          'courttv': 1,
#          'friday': 201,
#          'present': 1520,
#          'depict': 663,
#          'al': 379,
#          'retir': 162,
#          'relationship': 1327,
#          'exist': 1057,
#          'unit': 344,
#          'lot': 4778,
#          'live': 4477,
#          'roommat': 111,
#          'attempt': 1932,
#          'suicid': 355,
#          'build': 921,
#          'nois': 214,
#          'violat': 58,
#          'sneez': 10,
#          'midnight': 178,
#          'needless': 162,
#          'easili': 892,
#          'relat': 737,
#          'polanski': 106,
#          'tenant': 101,
#          'whole': 3080,
#          'descent': 91,
#          'paranoia': 93,
#          'mad': 664,
#          'final': 3153,
#          'half': 2094,
#          'rather': 2733,
#          'jar': 124,
#          'bizarr': 529,
#          'ebert': 71,
#          'total': 1948,
#          'unconvinc': 190,
#          'slap': 227,
#          'viciou': 116,
#          'star': 4447,
#          'individu': 409,
#          'moment': 2784,
#          'beauti': 3292,
#          'though': 4566,
#          'egyptolog': 2,
#          'overal': 1434,
#          'posit': 858,
#          'love': 9027,
#          'obnoxi': 178,
#          'portray': 1902,
#          'bernard': 75,
#          'fresson': 3,
#          'god': 1271,
#          'settl': 200,
#          'like': 22799,
#          'instead': 2190,
#          'theater': 1057,
#          'histori': 1338,
#          'boy': 2178,
#          'isabel': 80,
#          'adjani': 13,
#          'foxi': 15,
#          'almost': 3139,
#          'unbeliev': 563,
#          'give': 5792,
#          'agre': 779,
#          'occasion': 449,
#          'disparag': 8,
#          'remark': 570,
#          'made': 8362,
#          'suppos': 1924,
#          'low': 1870,
#          'key': 501,
#          'thought': 3773,
#          'fit': 866,
#          'found': 2608,
#          'perfectli': 637,
#          'sympathet': 239,
#          'lose': 828,
#          'bit': 3348,
#          'start': 4166,
#          'dress': 636,
#          'drag': 523,
#          'discern': 69,
#          'ye': 1551,
#          'obscur': 181,
#          'slow': 1207,
#          'captur': 852,
#          'alien': 702,
#          'qualiti': 1505,
#          'someth': 5122,
#          'done': 3096,
#          'dig': 216,
#          'refer': 687,
#          'point': 4238,
#          'weirdo': 44,
#          'deepli': 320,
#          'signific': 264,
#          'definit': 1856,
#          'pick': 1078,
#          'pocket': 81,
#          'chang': 2062,
#          'dvd': 2410,
#          'becam': 697,
#          'cult': 502,
#          'chines': 338,
#          'colleg': 509,
#          'student': 752,
#          'havnt': 2,
#          'broadcast': 160,
#          'channel4': 1,
#          'uk': 230,
#          'full': 1783,
#          'arti': 58,
#          'giddi': 20,
#          'pretent': 7,
#          'mediocr': 408,
#          'unreal': 99,
#          'spirit': 778,
#          'convey': 341,
#          'independ': 403,
#          'artist': 897,
#          'resist': 180,
#          'commercisli': 1,
#          'music': 4247,
#          'industri': 447,
#          'maintain': 210,
#          'puriti': 17,
#          'soul': 562,
#          'wouldnt': 10,
#          'sell': 414,
#          'dirti': 337,
#          'money': 2370,
#          'superfici': 143,
#          'diologu': 2,
#          'mainli': 393,
#          'pathet': 490,
#          'act': 8794,
#          'poor': 1899,
#          'sceenplay': 2,
#          'art': 1653,
#          'fantasi': 725,
#          'decent': 1178,
#          'mid': 318,
#          '70': 732,
#          'horror': 3717,
#          'flick': 1629,
#          'gate': 133,
#          'hell': 1032,
#          'nyc': 86,
#          'old': 4583,
#          'brownston': 14,
#          'around': 3616,
#          'cours': 2520,
#          'unwit': 7,
#          'model': 400,
#          'decid': 1786,
#          'space': 799,
#          'boyfriend': 433,
#          'fianc': 144,
#          'e': 797,
#          'disguis': 159,
#          'price': 335,
#          'sever': 1663,
#          'strang': 1114,
#          'neighbor': 239,
#          'attend': 279,
#          'birthday': 140,
#          'parti': 668,
#          'cat': 657,
#          'upon': 859,
#          'realtor': 6,
#          'hear': 1050,
#          'night': 2293,
#          'upstair': 47,
#          'priest': 262,
#          'whoa': 27,
#          'slimi': 71,
#          'lawyer': 246,
#          'chri': 421,
#          'sarandon': 55,
#          'poke': 105,
#          'long': 3540,
#          'creepi': 673,
#          'idea': 2638,
#          'creaki': 14,
#          'folk': 462,
#          'appear': 2567,
#          'fairli': 587,
#          'intrigu': 550,
#          'gore': 1055,
#          'parad': 100,
#          'normal': 770,
#          'toward': 922,
#          'tv': 2786,
#          'uncut': 74,
#          'version': 2410,
#          'better': 5749,
#          'companion': 137,
#          'piec': 1981,
#          'burnt': 49,
#          'offer': 1057,
#          '8': 897,
#          'david': 1025,
#          'soprano': 129,
#          'prais': 291,
#          'televis': 932,
#          'recent': 1089,
#          'devoid': 104,
#          'intellect': 37,
#          'passion': 449,
#          'know': 7514,
#          'alreadi': 1381,
#          'jame': 1069,
#          'gandolfini': 43,
#          'toni': 582,
#          'big': 3477,
#          'fat': 283,
#          'hole': 543,
#          'mob': 165,
#          'boss': 468,
#          'spoil': 399,
#          'b': 1306,
#          'tch': 17,
#          'wife': 2140,
#          'two': 6908,
#          'bratti': 20,
#          'sh': 102,
#          'brain': 601,
#          'guess': 1565,
#          'armpit': 10,
#          'america': 738,
#          'jersey': 58,
#          'woman': 2838,
#          'adulter': 24,
#          'unrepent': 8,
#          'murder': 2102,
#          'scumbag': 21,
#          'crew': 584,
#          'saturday': 222,
#          'skit': 138,
#          'worthi': 364,
#          'caricatur': 148,
#          'subordin': 14,
#          'fact': 3749,
#          'mobster': 68,
#          'offend': 217,
#          'appar': 1226,
#          'allow': 1026,
#          'without': 3268,
#          'judgment': 82,
#          'american': 2618,
#          'hardli': 613,
#          'entourag': 14,
#          'gorg': 14,
#          'emmi': 44,
#          'simpli': 1965,
#          'observ': 277,
#          'behav': 191,
#          'provid': 995,
#          'insight': 322,
#          'action': 3694,
#          'reaction': 386,
#          'realiti': 1050,
#          'fiction': 698,
#          'organ': 259,
#          'crime': 896,
#          'la': 614,
#          'godfath': 137,
#          'glorifi': 71,
#          'endors': 33,
#          'greedi': 91,
#          'violent': 560,
#          'corrupt': 265,
#          'lifestyl': 126,
#          'hair': 594,
#          'psychologist': 60,
#          'week': 662,
#          'month': 420,
#          'paltri': 16,
#          '13': 263,
#          'season': 1072,
#          'regular': 295,
#          'lunar': 7,
#          'eclips': 25,
#          'refus': 345,
#          'adher': 26,
#          'network': 236,
#          'structur': 282,
#          'line': 3458,
#          'nowher': 446,
#          'pop': 524,
#          'disappear': 355,
#          'backyard': 35,
#          'vermin': 14,
#          'brilliant': 1196,
#          'lack': 1821,
#          'soap': 304,
#          'opera': 429,
#          'tire': 459,
#          'clich': 1047,
#          'bore': 2549,
#          'housew': 30,
#          'self': 1185,
#          'serv': 615,
#          'irredeem': 10,
#          'italian': 563,
#          'heritag': 30,
#          'ssed': 1,
#          'enough': 3452,
#          'curl': 27,
#          'book': 2935,
#          'dant': 45,
#          'inferno': 19,
#          'spring': 162,
#          'mind': 2354,
#          'imdb': 704,
#          'noth': 4296,
#          'therefor': 345,
#          'breath': 303,
#          'fresh': 399,
#          'air': 842,
#          'busi': 802,
#          'pay': 924,
#          'cabl': 285,
#          'bill': 799,
#          'shield': 70,
#          'includ': 2020,
#          'ya': 105,
#          'west': 477,
#          'wing': 256,
#          'brilliantli': 248,
#          'errat': 31,
#          'written': 1616,
#          'boston': 71,
#          'legal': 121,
#          'best': 6424,
#          'comedi': 3686,
#          'last': 3158,
#          'decad': 476,
#          'arrest': 211,
#          'develop': 1595,
#          'lest': 25,
#          'forget': 821,
#          'age': 1726,
#          'nobodi': 462,
#          'shell': 80,
#          '40': 461,
#          'box': 813,
#          'pretti': 3665,
#          'hbo': 107,
#          '80': 899,
#          'continu': 1159,
#          'prove': 937,
#          'hack': 140,
#          'factori': 151,
#          'picket': 7,
#          'fenc': 82,
#          'prior': 192,
#          'northern': 67,
#          'exposur': 88,
#          'among': 783,
#          'wash': 156,
#          'fan': 3370,
#          'critic': 1071,
#          'late': 1309,
#          'worthless': 128,
#          'kin': 14,
#          'belong': 286,
#          'rot': 68,
#          'fish': 241,
#          'sleep': 568,
#          'kind': 3008,
#          'rent': 1256,
#          'coupl': 1894,
#          'ago': 1033,
#          'suck': 750,
#          'commerci': 392,
#          'lead': 2684,
#          'luck': 269,
#          'women': 1827,
#          'lie': 632,
#          'wrong': 1872,
#          'vulgar': 106,
#          'bother': 655,
#          '1': 2213,
#          'motiv': 466,
#          'creator': 219,
#          'account': 297,
#          'btk': 33,
#          'anim': 2483,
#          'right': 3554,
#          'activist': 39,
#          'monster': 932,
#          'respons': 535,
#          'involv': 1980,
#          'blatant': 104,
#          'disrespect': 58,
#          'exploit': 497,
#          'victim': 816,
#          'experi': 1548,
#          'disturb': 639,
#          'slaughterhous': 23,
#          'use': 5123,
#          'actual': 5065,
#          'name': 2917,
#          'hideou': 103,
#          'insult': 434,
#          'tragedi': 387,
#          'agenda': 86,
#          'awaken': 119,
#          'redraw': 2,
#          'ghost': 666,
#          'dragstrip': 3,
#          'hollow': 116,
#          'typic': 908,
#          '1950': 338,
#          'teen': 537,
#          'turmoil': 60,
#          'scienc': 556,
#          'concern': 621,
#          'group': 1147,
#          'kick': 587,
#          'hot': 703,
#          'rod': 78,
#          'club': 466,
#          'cannot': 1096,
#          'haunt': 521,
#          'hous': 2328,
#          'grace': 424,
#          'blaisdel': 3,
#          'creatur': 554,
#          'suit': 576,
#          'turn': 3880,
#          'jacki': 243,
#          'chan': 225,
#          'directori': 125,
#          'polic': 1105,
#          '1985': 63,
#          'influenti': 40,
#          'top': 1957,
#          'day': 4013,
#          'hong': 191,
#          'kong': 271,
#          'kung': 243,
#          'fu': 284,
#          'fierc': 52,
#          'gun': 872,
#          'urban': 204,
#          'later': 2202,
#          'popular': 643,
#          'hk': 74,
#          'john': 2222,
#          'woo': 100,
#          'ringo': 23,
#          'lam': 32,
#          'mix': 755,
#          'element': 1176,
#          'style': 1760,
#          'result': 1052,
#          'wild': 473,
#          'sound': 2228,
#          'ka': 31,
#          'kui': 5,
#          'protect': 314,
#          'wit': 739,
#          'brigitt': 24,
#          'lin': 41,
#          'soon': 1222,
#          'testifi': 24,
#          'power': 1957,
#          'gangster': 356,
#          'ring': 525,
#          'activ': 268,
#          'girlfriend': 684,
#          'young': 3664,
#          'maggi': 106,
#          'cheung': 39,
#          'subsequ': 167,
#          'role': 4300,
#          'heroic': 135,
#          'trio': 114,
#          'sequel': 1042,
#          'johnni': 328,
#          'savior': 31,
#          'corey': 52,
#          'yuen': 21,
#          'lai': 5,
#          'first': 9062,
#          'stunt': 286,
#          'badli': 662,
#          'hit': 1497,
#          'head': 2075,
#          'near': 843,
#          'eye': 2200,
#          'look': 10051,
#          'sharp': 223,
#          'glass': 238,
#          'team': 935,
#          'member': 879,
#          'got': 3583,
#          'bu': 199,
#          'stop': 1543,
#          'spit': 113,
#          'kidnapp': 26,
#          'windshield': 20,
#          'went': 1463,
#          'earli': 1605,
#          'stuntmen': 5,
#          'fli': 695,
#          'car': 1505,
#          'park': 489,
#          'flight': 188,
#          'asphalt': 5,
#          'hospit': 384,
#          'level': 1210,
#          'injuri': 75,
#          'credit': 1295,
#          'behind': 1280,
#          'imageri': 186,
#          'injur': 72,
#          'tasteless': 77,
#          'fortun': 373,
#          'plenti': 655,
#          'imagin': 1547,
#          'expect': 3007,
#          'legendari': 192,
#          'shop': 360,
#          'mall': 109,
#          'wildest': 16,
#          'abl': 1259,
#          'deliv': 1021,
#          'edit': 1250,
#          'true': 2333,
#          'perfect': 1778,
#          'ultra': 140,
#          'kinet': 18,
#          'compar': 1068,
#          'hollywood': 1920,
#          'effort': 1047,
#          'instanc': 341,
#          'interest': 4893,
#          'neg': 402,
#          'stand': 1463,
#          'especi': 2539,
#          'error': 171,
#          'screenplay': 735,
#          'accid': 344,
#          'add': 1147,
#          'necessarili': 180,
#          'sign': 503,
#          'script': 3342,
#          'dialogu': 1652,
#          'stab': 185,
#          'begin': 2905,
#          'shout': 156,
#          'scream': 690,
#          'face': 2292,
#          'drunken': 123,
#          'clown': 127,
#          'slapstick': 177,
#          'nightmar': 426,
#          'girl': 4064,
#          'inept': 187,
#          'otherwis': 670,
#          'genr': 1367,
#          'speak': 1129,
#          'loud': 438,
#          'clear': 818,
#          'stupidest': 34,
#          'viewer': 2047,
#          'thu': 418,
#          'light': 1555,
#          'comic': 1230,
#          'seriou': 989,
#          'forgiven': 63,
#          'fast': 897,
#          'speed': 304,
#          'impact': 401,
#          'wall': 505,
#          'adventur': 773,
#          'miracl': 127,
#          'sad': 1108,
#          'protector': 26,
#          'glickenhau': 5,
#          'pleas': 1253,
#          'audienc': 2675,
#          'return': 1174,
#          'invent': 328,
#          'today': 1282,
#          'insan': 339,
#          'somewhat': 965,
#          'flaw': 659,
#          '7': 904,
#          'delani': 4,
#          'sister': 1025,
#          'knew': 897,
#          'bravado': 18,
#          'courag': 192,
#          'pair': 345,
#          'sacrific': 167,
#          'term': 615,
#          'african': 284,
#          'lesson': 407,
#          'documentari': 1074,
#          'roll': 666,
#          'combin': 629,
#          'entertain': 2827,
#          ...})

# %%
extra_words = (new_vocabulary - original_vocabulary)
for word in extra_words:
    print(word)
    print(list_words[word])
# Out:
# optimist
# 62
# sophi
# 62
# banana
# 5019
# orchestr
# 62
# dubiou
# 62
# omin
# 62
# masterson
# 62

# %% [markdown]
# Banana seems to appear 5019 times.

# %% [markdown]
# ### (TODO) Build a new model
#
# Supposing that we believe something has changed about the underlying distribution of the words that our reviews are made up of, we need to create a new model. This way our new model will take into account whatever it is that has changed.
#
# To begin with, we will use the new vocabulary to create a bag of words encoding of the new data. We will then use this data to train a new XGBoost model.
#
# **NOTE:** Because we believe that the underlying distribution of words has changed it should follow that the original vocabulary that we used to construct a bag of words encoding of the reviews is no longer valid. This means that we need to be careful with our data. If we send an bag of words encoded review using the *original* vocabulary we should not expect any sort of meaningful results.
#
# In particular, this means that if we had deployed our XGBoost model like we did in the Web App notebook then we would need to implement this vocabulary change in the Lambda function as well.

# %%
new_XV = new_vectorizer.transform(new_X).toarray()

# %% [markdown]
# And a quick check to make sure that the newly encoded reviews have the correct length, which should be the size of the new vocabulary which we created.

# %%
len(new_XV[0])
# Out:
# 5000

# %% [markdown]
# Now that we have our newly encoded, newly collected data, we can split it up into a training and validation set so that we can train a new XGBoost model. As usual, we first split up the data, then save it locally and then upload it to S3.

# %%
import pandas as pd

# Earlier we shuffled the training dataset so to make things simple we can just assign
# the first 10 000 reviews to the validation set and use the remaining reviews for training.
new_val_X = pd.DataFrame(new_XV[:10000])
new_train_X = pd.DataFrame(new_XV[10000:])

new_val_y = pd.DataFrame(new_Y[:10000])
new_train_y = pd.DataFrame(new_Y[10000:])

# %% [markdown]
# In order to save some memory we will effectively delete the `new_X` variable. Remember that this contained a list of reviews and each review was a list of words. Note that once this cell has been executed you will need to read the new data in again if you want to work with it.

# %%
new_X = None

# %% [markdown]
# Next we save the new training and validation sets locally. Note that we overwrite the training and validation sets used earlier. This is mostly because the amount of space that we have available on our notebook instance is limited. Of course, you can increase this if you'd like but to do so may increase the cost of running the notebook instance.

# %%
pd.DataFrame(new_XV).to_csv(os.path.join(data_dir, 'new_data.csv'), header=False, index=False)

pd.concat([new_val_y, new_val_X], axis=1).to_csv(os.path.join(data_dir, 'new_validation.csv'), header=False, index=False)
pd.concat([new_train_y, new_train_X], axis=1).to_csv(os.path.join(data_dir, 'new_train.csv'), header=False, index=False)

# %% [markdown]
# Now that we've saved our data to the local instance, we can safely delete the variables to save on memory.

# %%
new_val_y = new_val_X = new_train_y = new_train_X = new_XV = None

# %% [markdown]
# Lastly, we make sure to upload the new training and validation sets to S3.
#
# **TODO:** Upload the new data as well as the new training and validation data sets to S3.

# %%
# TODO: Upload the new data and the new validation.csv and train.csv files in the data_dir directory to S3.
new_data_location = session.upload_data(os.path.join(data_dir, 'new_data.csv'), key_prefix=prefix)
new_val_location = session.upload_data(os.path.join(data_dir, 'new_validation.csv'), key_prefix=prefix)
new_train_location = session.upload_data(os.path.join(data_dir, 'new_train.csv'), key_prefix=prefix)

# %% [markdown]
# Once our new training data has been uploaded to S3, we can create a new XGBoost model that will take into account the changes that have occured in our data set.
#
# **TODO:** Create a new XGBoost estimator object.

# %%
# TODO: First, create a SageMaker estimator object for our model.
new_xgb = sagemaker.estimator.Estimator(container, # The location of the container we wish to use
                                    role,                                    # What is our current IAM Role
                                    train_instance_count=1,                  # How many compute instances
                                    train_instance_type='ml.m4.xlarge',      # What kind of compute instances
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                    sagemaker_session=session)


# TODO: Then set the algorithm specific parameters. You may wish to use the same parameters that were
#       used when training the original model.

new_xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# Once the model has been created, we can train it with our new data.
#
# **TODO:** Train the new XGBoost model.

# %%
# TODO: First, make sure that you create s3 input objects so that SageMaker knows where to
#       find the training and validation data.
s3_new_input_train = sagemaker.s3_input(s3_data=new_train_location, content_type='csv')
s3_new_input_validation = sagemaker.s3_input(s3_data=new_val_location, content_type='csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
# TODO: Using the new validation and training data, 'fit' your new model.
new_xgb.fit({'train': s3_new_input_train, 'validation': s3_new_input_validation})
# Out:
# 2022-04-29 19:39:44 Starting - Starting the training job......
# 2022-04-29 19:40:22 Starting - Preparing the instances for training......
# 2022-04-29 19:41:40 Downloading - Downloading input data......
# 2022-04-29 19:42:16 Training - Downloading the training image.....Arguments: train
# [2022-04-29:19:43:25:INFO] Running standalone xgboost training.
# [2022-04-29:19:43:25:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8528.84mb
# [2022-04-29:19:43:25:INFO] Determined delimiter of CSV input is ','
# [19:43:25] S3DistributionType set as FullyReplicated
# [19:43:27] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2022-04-29:19:43:27:INFO] Determined delimiter of CSV input is ','
# [19:43:27] S3DistributionType set as FullyReplicated
# [19:43:29] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
#
# 2022-04-29 19:43:21 Training - Training image download completed. Training in progress.[19:43:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 4 pruned nodes, max_depth=5
# [0]#011train-error:0.3136#011validation-error:0.3164
# Multiple eval metrics have been passed: 'validation-error' will be used for early stopping.
# Will train until validation-error hasn't improved in 10 rounds.
# [19:43:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 8 pruned nodes, max_depth=5
# [1]#011train-error:0.284533#011validation-error:0.2915
# [19:43:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=5
# [2]#011train-error:0.278133#011validation-error:0.2846
# [19:43:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 12 pruned nodes, max_depth=5
# [3]#011train-error:0.2688#011validation-error:0.276
# [19:43:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=5
# [4]#011train-error:0.265667#011validation-error:0.2728
# [19:43:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=5
# [5]#011train-error:0.254267#011validation-error:0.2642
# [19:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 10 pruned nodes, max_depth=5
# [6]#011train-error:0.2524#011validation-error:0.2625
# [19:43:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 6 pruned nodes, max_depth=5
# [7]#011train-error:0.247067#011validation-error:0.258
# [19:43:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=5
# [8]#011train-error:0.247267#011validation-error:0.2542
# [19:43:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 16 pruned nodes, max_depth=5
# [9]#011train-error:0.2446#011validation-error:0.2514
# [19:43:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=5
# [10]#011train-error:0.2368#011validation-error:0.2456
# [19:43:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 8 pruned nodes, max_depth=5
# [11]#011train-error:0.232933#011validation-error:0.2414
# [19:43:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=5
# [12]#011train-error:0.226867#011validation-error:0.2384
# [19:43:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [13]#011train-error:0.222467#011validation-error:0.2348
# [19:43:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 4 pruned nodes, max_depth=5
# [14]#011train-error:0.2164#011validation-error:0.2288
# [19:44:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 12 pruned nodes, max_depth=5
# [15]#011train-error:0.213267#011validation-error:0.2286
# [19:44:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=5
# [16]#011train-error:0.211#011validation-error:0.2264
# [19:44:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=5
# [17]#011train-error:0.209333#011validation-error:0.2272
# [19:44:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [18]#011train-error:0.206933#011validation-error:0.224
# [19:44:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [19]#011train-error:0.2036#011validation-error:0.2218
# [19:44:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 10 pruned nodes, max_depth=5
# [20]#011train-error:0.201333#011validation-error:0.2195
# [19:44:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=5
# [21]#011train-error:0.198867#011validation-error:0.2195
# [19:44:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=5
# [22]#011train-error:0.196#011validation-error:0.2173
# [19:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 8 pruned nodes, max_depth=5
# [23]#011train-error:0.193733#011validation-error:0.2138
# [19:44:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [24]#011train-error:0.1918#011validation-error:0.2137
# [19:44:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 10 pruned nodes, max_depth=5
# [25]#011train-error:0.190067#011validation-error:0.21
# [19:44:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [26]#011train-error:0.189467#011validation-error:0.2113
# [19:44:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=5
# [27]#011train-error:0.186067#011validation-error:0.2088
# [19:44:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 6 pruned nodes, max_depth=5
# [28]#011train-error:0.1834#011validation-error:0.2068
# [19:44:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [29]#011train-error:0.1826#011validation-error:0.2043
# [19:44:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [30]#011train-error:0.181067#011validation-error:0.2038
# [19:44:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=5
# [31]#011train-error:0.1776#011validation-error:0.2008
# [19:44:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [32]#011train-error:0.176133#011validation-error:0.2002
# [19:44:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 8 pruned nodes, max_depth=5
# [33]#011train-error:0.173933#011validation-error:0.1987
# [19:44:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 16 pruned nodes, max_depth=5
# [34]#011train-error:0.1726#011validation-error:0.1983
# [19:44:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [35]#011train-error:0.172267#011validation-error:0.1973
# [19:44:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [36]#011train-error:0.169667#011validation-error:0.197
# [19:44:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 4 pruned nodes, max_depth=5
# [37]#011train-error:0.169333#011validation-error:0.1948
# [19:44:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 4 pruned nodes, max_depth=5
# [38]#011train-error:0.167667#011validation-error:0.1946
# [19:44:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 12 pruned nodes, max_depth=5
# [39]#011train-error:0.167#011validation-error:0.1938
# [19:44:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 16 pruned nodes, max_depth=5
# [40]#011train-error:0.1666#011validation-error:0.1934
# [19:44:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [41]#011train-error:0.166267#011validation-error:0.1927
# [19:44:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [42]#011train-error:0.164933#011validation-error:0.192
# [19:44:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [43]#011train-error:0.1634#011validation-error:0.1934
# [19:44:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [44]#011train-error:0.163667#011validation-error:0.1926
# [19:44:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [45]#011train-error:0.162#011validation-error:0.1921
# [19:44:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [46]#011train-error:0.161#011validation-error:0.1918
# [19:45:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [47]#011train-error:0.1598#011validation-error:0.1922
# [19:45:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [48]#011train-error:0.158733#011validation-error:0.1909
# [19:45:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [49]#011train-error:0.157067#011validation-error:0.1895
# [19:45:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [50]#011train-error:0.156267#011validation-error:0.1887
# [19:45:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [51]#011train-error:0.155933#011validation-error:0.1892
# [19:45:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [52]#011train-error:0.156133#011validation-error:0.1888
# [19:45:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [53]#011train-error:0.154933#011validation-error:0.1873
# [19:45:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [54]#011train-error:0.1534#011validation-error:0.1867
# [19:45:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [55]#011train-error:0.1528#011validation-error:0.1851
# [19:45:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [56]#011train-error:0.152533#011validation-error:0.1844
# [19:45:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=5
# [57]#011train-error:0.150533#011validation-error:0.1852
# [19:45:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [58]#011train-error:0.1502#011validation-error:0.1855
# [19:45:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=5
# [59]#011train-error:0.1492#011validation-error:0.1849
# [19:45:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=5
# [60]#011train-error:0.148333#011validation-error:0.1844
# [19:45:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [61]#011train-error:0.146067#011validation-error:0.1841
# [19:45:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [62]#011train-error:0.145133#011validation-error:0.1833
# [19:45:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [63]#011train-error:0.145333#011validation-error:0.1831
# [19:45:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [64]#011train-error:0.143867#011validation-error:0.1823
# [19:45:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [65]#011train-error:0.1428#011validation-error:0.1827
# [19:45:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [66]#011train-error:0.142867#011validation-error:0.1823
# [19:45:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [67]#011train-error:0.141933#011validation-error:0.1833
# [19:45:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=5
# [68]#011train-error:0.141733#011validation-error:0.1827
# [19:45:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [69]#011train-error:0.141133#011validation-error:0.1821
# [19:45:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [70]#011train-error:0.140267#011validation-error:0.1828
# [19:45:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [71]#011train-error:0.139933#011validation-error:0.1828
# [19:45:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [72]#011train-error:0.139267#011validation-error:0.1816
# [19:45:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [73]#011train-error:0.139333#011validation-error:0.1808
# [19:45:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [74]#011train-error:0.139933#011validation-error:0.1798
# [19:45:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [75]#011train-error:0.139667#011validation-error:0.1799
# [19:45:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [76]#011train-error:0.138467#011validation-error:0.1798
# [19:45:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [77]#011train-error:0.1378#011validation-error:0.1784
# [19:45:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [78]#011train-error:0.1374#011validation-error:0.1788
# [19:46:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=5
# [79]#011train-error:0.136467#011validation-error:0.1793
# [19:46:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [80]#011train-error:0.1364#011validation-error:0.1797
# [19:46:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [81]#011train-error:0.1358#011validation-error:0.1789
# [19:46:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [82]#011train-error:0.134533#011validation-error:0.1772
# [19:46:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [83]#011train-error:0.134333#011validation-error:0.1778
# [19:46:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [84]#011train-error:0.1334#011validation-error:0.1772
# [19:46:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 12 pruned nodes, max_depth=5
# [85]#011train-error:0.132933#011validation-error:0.1774
# [19:46:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=5
# [86]#011train-error:0.132467#011validation-error:0.1782
# [19:46:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [87]#011train-error:0.1314#011validation-error:0.1782
# [19:46:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [88]#011train-error:0.130333#011validation-error:0.1789
# [19:46:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [89]#011train-error:0.1302#011validation-error:0.1789
# [19:46:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [90]#011train-error:0.13#011validation-error:0.177
# [19:46:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 14 pruned nodes, max_depth=5
# [91]#011train-error:0.1292#011validation-error:0.1763
# [19:46:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [92]#011train-error:0.1292#011validation-error:0.1771
# [19:46:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [93]#011train-error:0.128667#011validation-error:0.1769
# [19:46:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [94]#011train-error:0.127867#011validation-error:0.1774
# [19:46:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [95]#011train-error:0.127533#011validation-error:0.1768
# [19:46:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=5
# [96]#011train-error:0.127067#011validation-error:0.1771
# [19:46:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [97]#011train-error:0.126667#011validation-error:0.1769
# [19:46:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [98]#011train-error:0.126067#011validation-error:0.1776
# [19:46:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [99]#011train-error:0.1264#011validation-error:0.1768
# [19:46:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [100]#011train-error:0.1254#011validation-error:0.1756
# [19:46:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [101]#011train-error:0.125333#011validation-error:0.1763
# [19:46:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [102]#011train-error:0.1232#011validation-error:0.1756
# [19:46:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [103]#011train-error:0.122667#011validation-error:0.1755
# [19:46:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [104]#011train-error:0.123067#011validation-error:0.1753
# [19:46:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [105]#011train-error:0.122733#011validation-error:0.1754
# [19:46:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [106]#011train-error:0.1216#011validation-error:0.1755
# [19:46:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [107]#011train-error:0.121333#011validation-error:0.175
# [19:46:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [108]#011train-error:0.120733#011validation-error:0.1752
# [19:46:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [109]#011train-error:0.120533#011validation-error:0.1746
# [19:46:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [110]#011train-error:0.121#011validation-error:0.1749
# [19:47:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [111]#011train-error:0.120533#011validation-error:0.1736
# [19:47:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 12 pruned nodes, max_depth=5
# [112]#011train-error:0.120333#011validation-error:0.1731
# [19:47:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=5
# [113]#011train-error:0.1208#011validation-error:0.175
# [19:47:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [114]#011train-error:0.120067#011validation-error:0.1747
# [19:47:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [115]#011train-error:0.119467#011validation-error:0.1746
# [19:47:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [116]#011train-error:0.119#011validation-error:0.1744
# [19:47:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [117]#011train-error:0.118733#011validation-error:0.1738
#
# 2022-04-29 19:47:23 Uploading - Uploading generated training model[19:47:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [118]#011train-error:0.118267#011validation-error:0.1735
# [19:47:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=5
# [119]#011train-error:0.117733#011validation-error:0.1735
# [19:47:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [120]#011train-error:0.116933#011validation-error:0.174
# [19:47:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 18 pruned nodes, max_depth=5
# [121]#011train-error:0.117067#011validation-error:0.1744
# [19:47:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [122]#011train-error:0.116533#011validation-error:0.174
# Stopping. Best iteration:
# [112]#011train-error:0.120333#011validation-error:0.1731
#
# 2022-04-29 19:47:29 Completed - Training job completed
# Training seconds: 349
# Billable seconds: 349

# %% [markdown]
# ### (TODO) Check the new model
#
# So now we have a new XGBoost model that we believe more accurately represents the state of the world at this time, at least in how it relates to the sentiment analysis problem that we are working on. The next step is to double check that our model is performing reasonably.
#
# To do this, we will first test our model on the new data.
#
# **Note:** In practice this is a pretty bad idea. We already trained our model on the new data, so testing it shouldn't really tell us much. In fact, this is sort of a textbook example of leakage. We are only doing it here so that we have a numerical baseline.
#
# **Question:** How might you address the leakage problem?

# %% [markdown]
# First, we create a new transformer based on our new XGBoost model.
#
# **TODO:** Create a transformer object from the newly created XGBoost model.

# %%
# TODO: Create a transformer object from the new_xgb model
new_xgb_transformer = new_xgb.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# Next we test our model on the new data.
#
# **TODO:** Use the transformer object to transform the new data (stored in the `new_data_location` variable)

# %%
# TODO: Using new_xgb_transformer, transform the new_data_location data. You may wish to
#       'wait' for the transform job to finish.
new_xgb_transformer.transform(new_data_location, content_type='text/csv', split_type='Line')
new_xgb_transformer.wait()
# Out:
# ......................................Arguments: serve
# [2022-04-29 20:08:10 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-04-29 20:08:10 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-04-29 20:08:10 +0000] [1] [INFO] Using worker: gevent
# [2022-04-29 20:08:10 +0000] [21] [INFO] Booting worker with pid: 21
# [2022-04-29 20:08:10 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-04-29 20:08:10 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-04-29 20:08:10 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:20:08:10:INFO] Model loaded successfully for worker : 22
# [2022-04-29:20:08:10:INFO] Model loaded successfully for worker : 21
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:20:08:10:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:20:08:10:INFO] Model loaded successfully for worker : 24
# 2022-04-29T20:08:14.095:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2022-04-29:20:08:17:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:17:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:17:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:17:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:17:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:17:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:17:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:17:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:18:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:18:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:18:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:18:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:18:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:18:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:18:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:18:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:21:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:21:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:21:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:21:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:21:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:21:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:21:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:21:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:21:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:21:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:21:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:21:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:22:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:22:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:22:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:22:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:25:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:25:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:25:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:25:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:25:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:25:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:25:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:25:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:25:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:25:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:25:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:25:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:25:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:25:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:25:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:25:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:32:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:32:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:33:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:33:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:32:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:32:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:33:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:33:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:33:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:33:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:33:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:33:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:33:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:33:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:33:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:33:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:36:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:36:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:36:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:36:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:37:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:37:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:37:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:37:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:40:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:40:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:40:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:40:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:40:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:40:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:40:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:40:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:40:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:40:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:40:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:40:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:40:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:40:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:40:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:40:INFO] Determined delimiter of CSV input is ','
#
# [2022-04-29:20:08:47:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:47:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:47:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:47:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:48:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:48:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:48:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:48:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:48:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:48:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:48:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:48:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:48:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:48:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:48:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:48:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:51:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:51:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:51:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:51:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:51:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:51:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:51:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:51:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:51:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:51:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:51:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:51:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:52:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:52:INFO] Sniff delimiter as ','
# [2022-04-29:20:08:52:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:08:52:INFO] Determined delimiter of CSV input is ','

# %% [markdown]
# Copy the results to our local instance.

# %%
# !aws s3 cp --recursive $new_xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-1-984973086835/xgboost-2022-04-29-20-01-54-979/new_data.csv.out to ../data/sentiment_update/new_data.csv.out

# %% [markdown]
# And see how well the model did.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'new_data.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
accuracy_score(new_Y, predictions)
# Out:
# 0.85856

# %% [markdown]
# As expected, since we trained the model on this data, our model performs pretty well. So, we have reason to believe that our new XGBoost model is a "better" model.
#
# However, before we start changing our deployed model, we should first make sure that our new model isn't too different. In other words, if our new model performed really poorly on the original test data then this might be an indication that something else has gone wrong.
#
# To start with, since we got rid of the variable that stored the original test reviews, we will read them in again from the cache that we created in Step 3. Note that we need to make sure that we read in the original test data after it has been pre-processed with `nltk` but before it has been bag of words encoded. This is because we need to use the new vocabulary instead of the original one.

# %%
cache_data = None
with open(os.path.join(cache_dir, "preprocessed_data.pkl"), "rb") as f:
            cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", "preprocessed_data.pkl")
            
test_X = cache_data['words_test']
test_Y = cache_data['labels_test']

# Here we set cache_data to None so that it doesn't occupy memory
cache_data = None
# Out:
# Read preprocessed data from cache file: preprocessed_data.pkl

# %% [markdown]
# Once we've loaded the original test reviews, we need to create a bag of words encoding of them using the new vocabulary that we created, based on the new data.
#
# **TODO:** Transform the original test data using the new vocabulary.

# %%
# TODO: Use the new_vectorizer object that you created earlier to transform the test_X data.
test_X = new_vectorizer.transform(test_X).toarray()

# %% [markdown]
# Now that we have correctly encoded the original test data, we can write it to the local instance, upload it to S3 and test it.

# %%
pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

# %%
test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)

# %%
new_xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')
new_xgb_transformer.wait()
# Out:
# .....................................Arguments: serve
# [2022-04-29 20:16:08 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-04-29 20:16:08 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-04-29 20:16:08 +0000] [1] [INFO] Using worker: gevent
# [2022-04-29 20:16:08 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-04-29 20:16:08 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-04-29 20:16:08 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:20:16:08:INFO] Model loaded successfully for worker : 22
# [2022-04-29 20:16:08 +0000] [25] [INFO] Booting worker with pid: 25
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:20:16:08:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:20:16:08:INFO] Model loaded successfully for worker : 24
# Arguments: serve
# [2022-04-29 20:16:08 +0000] [1] [INFO] Starting gunicorn 19.9.0
# [2022-04-29 20:16:08 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2022-04-29 20:16:08 +0000] [1] [INFO] Using worker: gevent
# [2022-04-29 20:16:08 +0000] [22] [INFO] Booting worker with pid: 22
# [2022-04-29 20:16:08 +0000] [23] [INFO] Booting worker with pid: 23
# [2022-04-29 20:16:08 +0000] [24] [INFO] Booting worker with pid: 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:20:16:08:INFO] Model loaded successfully for worker : 22
# [2022-04-29 20:16:08 +0000] [25] [INFO] Booting worker with pid: 25
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:20:16:08:INFO] Model loaded successfully for worker : 23
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:20:16:08:INFO] Model loaded successfully for worker : 24
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:20:16:08:INFO] Model loaded successfully for worker : 25
# /opt/amazon/lib/python3.7/site-packages/gunicorn/workers/ggevent.py:65: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util.ssl_ (/opt/amazon/lib/python3.7/site-packages/urllib3/util/ssl_.py)', 'urllib3.util (/opt/amazon/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   monkey.patch_all(subprocess=True)
# [2022-04-29:20:16:08:INFO] Model loaded successfully for worker : 25
# 2022-04-29T20:16:12.191:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2022-04-29:20:16:16:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:16:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:16:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:16:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:16:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:16:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:16:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:16:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:16:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:16:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:16:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:16:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:16:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:16:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:16:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:16:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:19:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:19:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:19:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:19:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:20:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:20:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:20:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:20:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:20:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:20:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:20:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:20:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:20:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:20:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:20:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:20:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:24:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:24:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:24:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:24:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:27:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:27:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:27:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:27:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:27:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:27:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:27:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:27:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:27:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:27:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:28:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:28:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:27:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:27:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:28:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:28:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:31:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:31:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:31:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:31:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:31:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:31:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:31:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:31:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:35:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:35:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:35:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:35:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:35:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:35:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:35:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:35:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:35:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:35:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:35:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:35:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:35:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:35:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:35:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:35:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:38:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:38:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:38:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:38:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:39:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:39:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:39:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:39:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:38:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:38:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:38:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:38:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:39:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:39:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:39:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:39:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:42:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:42:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:42:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:42:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:42:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:42:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:42:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:43:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:43:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:43:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:43:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:42:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:43:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:43:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:43:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:43:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:46:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:47:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:47:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:46:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:47:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:47:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:50:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:50:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:50:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:50:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:50:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:50:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:50:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:50:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:50:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:50:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:50:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:50:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:50:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:50:INFO] Determined delimiter of CSV input is ','
# [2022-04-29:20:16:50:INFO] Sniff delimiter as ','
# [2022-04-29:20:16:50:INFO] Determined delimiter of CSV input is ','

# %%
# !aws s3 cp --recursive $new_xgb_transformer.output_path $data_dir
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-124-1dab5f3b624f> in <module>
# ----> 1 get_ipython().system('aws s3 cp --recursive $new_xgb_transformer.output_path $data_dir')
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#     648                 self.user_ns['_exit_code'] = system(cmd)
#     649         else:
# --> 650             self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#     651
#     652     # Ensure new system_piped implementation is used
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     155                 child = pexpect.spawnb(self.sh, args=['-c', cmd]) # Pexpect-U
#     156             else:
# --> 157                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     158             flush = sys.stdout.flush
#     159             while True:
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/pexpect/pty_spawn.py in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     203             self.name = '<pexpect factory incomplete>'
#     204         else:
# --> 205             self._spawn(command, args, preexec_fn, dimensions)
#     206         self.use_poll = use_poll
#     207
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/pexpect/pty_spawn.py in _spawn(self, command, args, preexec_fn, dimensions)
#     302
#     303         self.ptyproc = self._spawnpty(self.args, env=self.env,
# --> 304                                      cwd=self.cwd, **kwargs)
#     305
#     306         self.pid = self.ptyproc.pid
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/pexpect/pty_spawn.py in _spawnpty(self, args, **kwargs)
#     313     def _spawnpty(self, args, **kwargs):
#     314         '''Spawn a pty and return an instance of PtyProcess.'''
# --> 315         return ptyprocess.PtyProcess.spawn(args, **kwargs)
#     316
#     317     def close(self, force=True):
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/ptyprocess/ptyprocess.py in spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions, pass_fds)
#     228
#     229         if use_native_pty_fork:
# --> 230             pid, fd = pty.fork()
#     231         else:
#     232             # Use internal fork_pty, for Solaris
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/pty.py in fork()
#      95
#      96     master_fd, slave_fd = openpty()
# ---> 97     pid = os.fork()
#      98     if pid == CHILD:
#      99         # Establish a new session.
#
# OSError: [Errno 12] Cannot allocate memory

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
accuracy_score(test_Y, predictions)
# Out:
# 0.86272

# %% [markdown]
# It would appear that our new XGBoost model is performing quite well on the old test data. This gives us some indication that our new model should be put into production and replace our original model.

# %% [markdown]
# ## Step 6: (TODO) Updating the Model
#
# So we have a new model that we'd like to use instead of one that is already deployed. Furthermore, we are assuming that the model that is already deployed is being used in some sort of application. As a result, what we want to do is update the existing endpoint so that it uses our new model.
#
# Of course, to do this we need to create an endpoint configuration for our newly created model.
#
# First, note that we can access the name of the model that we created above using the `model_name` property of the transformer. The reason for this is that in order for the transformer to create a batch transform job it needs to first create the model object inside of SageMaker. Since we've sort of already done this we should take advantage of it.

# %%
new_xgb_transformer.model_name
# Out:
# 'xgboost-2022-04-29-19-39-44-538'

# %% [markdown]
# Next, we create an endpoint configuration using the low level approach of creating the dictionary object which describes the endpoint configuration we want.
#
# **TODO:** Using the low level approach, create a new endpoint configuration. Don't forget that it needs a name and that the name needs to be unique. If you get stuck, try looking at the Boston Housing Low Level Deployment tutorial notebook.

# %%
from time import gmtime, strftime


# TODO: Give our endpoint configuration a name. Remember, it needs to be unique.
new_xgb_endpoint_config_name = "sentiment-update-xgboost-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# TODO: Using the SageMaker Client, construct the endpoint configuration.
new_xgb_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = new_xgb_endpoint_config_name,
                            ProductionVariants = [{
                                "InstanceType": "ml.m4.xlarge",
                                "InitialVariantWeight": 1,
                                "InitialInstanceCount": 1,
                                "ModelName": new_xgb_transformer.model_name,
                                "VariantName": "XGB-Model"
                            }])

# %% [markdown]
# Once the endpoint configuration has been constructed, it is a straightforward matter to ask SageMaker to update the existing endpoint so that it uses the new endpoint configuration.
#
# Of note here is that SageMaker does this in such a way that there is no downtime. Essentially, SageMaker deploys the new model and then updates the original endpoint so that it points to the newly deployed model. After that, the original model is shut down. This way, whatever app is using our endpoint won't notice that we've changed the model that is being used.
#
# **TODO:** Use the SageMaker Client to update the endpoint that you deployed earlier.

# %%
# TODO: Update the xgb_predictor.endpoint so that it uses new_xgb_endpoint_config_name.
session.sagemaker_client.update_endpoint(EndpointName=xgb_predictor.endpoint, EndpointConfigName=new_xgb_endpoint_config_name)
# Out:
# {'EndpointArn': 'arn:aws:sagemaker:us-east-1:984973086835:endpoint/xgboost-2022-04-29-18-18-09-582',
#  'ResponseMetadata': {'RequestId': '6fe321cc-7983-4844-be64-817ba01788aa',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '6fe321cc-7983-4844-be64-817ba01788aa',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '99',
#    'date': 'Fri, 29 Apr 2022 20:24:53 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# And, as is generally the case with SageMaker requests, this is being done in the background so if we want to wait for it to complete we need to call the appropriate method.

# %%
session.wait_for_endpoint(xgb_predictor.endpoint)
# Out:
# ----------!
# {'EndpointName': 'xgboost-2022-04-29-18-18-09-582',
#  'EndpointArn': 'arn:aws:sagemaker:us-east-1:984973086835:endpoint/xgboost-2022-04-29-18-18-09-582',
#  'EndpointConfigName': 'sentiment-update-xgboost-endpoint-config-2022-04-29-20-24-28',
#  'ProductionVariants': [{'VariantName': 'XGB-Model',
#    'DeployedImages': [{'SpecifiedImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:1',
#      'ResolvedImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost@sha256:9db4760573a8c55acd561e99d28329dbd3c8270732b74df39b90e8d5e81b604f',
#      'ResolutionTime': datetime.datetime(2022, 4, 29, 20, 24, 55, 106000, tzinfo=tzlocal())}],
#    'CurrentWeight': 1.0,
#    'DesiredWeight': 1.0,
#    'CurrentInstanceCount': 1,
#    'DesiredInstanceCount': 1}],
#  'EndpointStatus': 'InService',
#  'CreationTime': datetime.datetime(2022, 4, 29, 19, 1, 40, 398000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2022, 4, 29, 20, 29, 48, 698000, tzinfo=tzlocal()),
#  'ResponseMetadata': {'RequestId': '65ab11d8-f920-44a7-b765-110b8c9169e6',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '65ab11d8-f920-44a7-b765-110b8c9169e6',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '742',
#    'date': 'Fri, 29 Apr 2022 20:29:59 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Step 7: Delete the Endpoint
#
# Of course, since we are done with the deployed endpoint we need to make sure to shut it down, otherwise we will continue to be charged for it.

# %%
xgb_predictor.delete_endpoint()

# %% [markdown]
# ## Some Additional Questions
#
# This notebook is a little different from the other notebooks in this module. In part, this is because it is meant to be a little bit closer to the type of problem you may face in a real world scenario. Of course, this problem is a very easy one with a prescribed solution, but there are many other interesting questions that we did not consider here and that you may wish to consider yourself.
#
# For example,
# - What other ways could the underlying distribution change?
# - Is it a good idea to re-train the model using only the new data?
# - What would change if the quantity of new data wasn't large. Say you only received 500 samples?

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
